# %% [markdown]
# # Evaluation & Storytelling — Leuven ↔ Brussels Commuter Delays
#
# **Business goal:** warn Leuven↔Brussels commuters that their train is going to be delayed, roughly one hour ahead of time.
#
# **Where we left off.** Modeling scored a persistence baseline (predict that the current delay carries through unchanged, test MAE 0.919 min) against a `GradientBoostingRegressor` (test MAE 0.859 min) and saved both sets of predictions, alongside the actual delay, to `model_predictions.csv`.
#
# **This stage is different.** Today isn't graded on squeezing out more accuracy, rather it's graded on the story. Who does this model serve? What decision changes because of it? What does it cost to get wrong, in each direction? What would you actually ship first? Work through the guiding questions below and build your own answers.

# %%
import os

# make "../../data/..." paths resolve whether Jupyter was launched from the repo root or from notebooks/
if not os.path.isdir("../../data") and os.path.isdir("data"):
    os.chdir("notebooks/assignment_notebooks")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

PREDICTIONS_PATH = "../../data/checkpoints/model_predictions.csv"

predictions = pd.read_csv(PREDICTIONS_PATH)
predictions.head()

# %% [markdown]
# ## 📊 How good is "good enough" to warn a commuter, one hour ahead?

# %% [markdown]
# ## 🚨 What's the cost of a false alarm vs. a missed warning, and who pays it?

# %% [markdown]
# ## 🎤 How would you explain this model's value to a commuter, or to a non-technical product owner, in two minutes?

# %% [markdown]
# ## 📦 What ships as v1? What's explicitly out of scope for now?

# %% [markdown]
# ## 🗺️ Bonus: a Folium map of the corridor stations, colored/sized by average delay or by model error
