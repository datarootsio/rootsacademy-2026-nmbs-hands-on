# %% [markdown]
# # Modeling — Leuven ↔ Brussels Commuter Delays
#
# **Business goal:** warn Leuven↔Brussels commuters that their train is going to be delayed, roughly one hour ahead of time.
#
# **Where we left off.** Feature Engineering turned the corridor data into three ready-to-use tables; `train.parquet`, `val.parquet`, `test.parquet`, one row per train run reaching Leuven, split chronologically (train: Jan–Apr, val: May, test: Jun–Jul). The target is `delay_arr_min`: how many minutes late the train arrives at Leuven.

# %%
import os

# make "../../data/..." paths resolve whether Jupyter was launched from the repo root or from notebooks/
if not os.path.isdir("../../data") and os.path.isdir("data"):
    os.chdir("notebooks/assignment_notebooks")

# %%
import pandas as pd
import numpy as np

TRAIN_PATH = "../../data/checkpoints/train.parquet"  # use these checkpoints if your group didn't finish (or hasn't gotten to) Feature Engineering yet -- same path either way
VAL_PATH = "../../data/checkpoints/val.parquet"
TEST_PATH = "../../data/checkpoints/test.parquet"

train = pd.read_parquet(TRAIN_PATH)
val = pd.read_parquet(VAL_PATH)
test = pd.read_parquet(TEST_PATH)

train.shape, val.shape, test.shape

# %% [markdown]
# ## 🤔 What would a good baseline model be in this case?

# %% [markdown]
# ## 🤔 How will we measure performance?

# %% [markdown]
# ## 🔧 Train some baselines. Who can get the best baseline that is still a baseline?

# %% [markdown]
# ## 🔧 Try to beat your baseline (once, modestly, not a tuning marathon)

# %% [markdown]
# ## Wrapping Up
#
# Stage 5 (Evaluation & storytelling) will want to look at actual vs. predicted delay per run, for both your best baseline and your model, side by side.
